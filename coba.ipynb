# %%
# import matplotlib.pyplot as plt
# import numpy as np

# np.random.seed(19680801)
# data = np.random.randn(2, 100)

# fig, axs = plt.subplots(2, 2, figsize=(5, 5))
# axs[0, 0].hist(data[0])
# axs[1, 0].scatter(data[0], data[1])
# axs[0, 1].plot(data[0], data[1])
# axs[1, 1].hist2d(data[0], data[1])

# plt.show()




# import numpy as np 
# import statsmodels.api as sm 
# import pylab as py 

# # np.random generates different random numbers 
# # whenever the code is executed 
# # Note: When you execute the same code 
# # the graph look different than shown below. 

# # Random data points generated 
# data_points = np.random.normal(0, 1, 100)	 

# sm.qqplot(data_points, line ='45') 
# py.show() 



# import pandas as pd

# df = pd.read_excel ("nilai.xlsx")
# print (df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-feb63b2b4f2c> in <module>
#      35 import pandas as pd
#      36
# ---> 37 df = pd.read_excel ("nilai.xlsx")
#      38 print (df)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
# import pandas as pd


# # coba = df['nilai uts'].describe()
# # df['nilai uts']
# import numpy as np 
# import statsmodels.api as sm 
# import pylab as py 

# df = pd.read_excel('nilai.xls')
# data_points = df['nilai uts']
# nilai_uts = data_points.to_numpy()
# # nilai_uts
# sm.qqplot(nilai_uts, line ='45') 
# py.show()

# data_points = np.random.normal(0, 1, 100)
# data_points

# %%
# qq plot
import numpy as np 
import pylab 
import scipy.stats as stats
import pandas as pd

df = pd.read_excel('nilai.xls')
data_points = df['nilai uts']
# nilai_uts = data_points.to_numpy()
stats.probplot(data_points, dist="norm", plot=pylab)
pylab.show()

# %%
# histogram
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('nilai.xls')
data_points = df['nilai uts']
plt.hist(data_points, bins=10)
plt.show()

# %%
# Scatter Plot
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel('nilai.xls')

x = df['nilai uts']
y = df['nomor mahasiswa']

plt.scatter(x, y)
plt.show()
